# %%
import pandas as pd
df=pd.read_csv("C:/Users/KEERTHANA/Downloads/student_dataset_10000_rows.CSV")

# %%
df
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
df.loc[df["attendance"]<75]
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 4               5          52            8               6
# 5               7          40            9              10
# ...           ...         ...          ...             ...
# 9990            4          72            8               6
# 9994            4          53            7               8
# 9995            2          58            9               7
# 9997           10          44            8               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
df.loc[(df["attendance"]>75)&(df["attendance"]<90)]
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 7               3          86            7               3
# 9              11          77            4               9
# 16              3          76            8              10
# 17              6          80            8              10
# 20              8          88            7               4
# ...           ...         ...          ...             ...
# 9971           11          81            9               6
# 9975           10          76            6               3
# 9979           11          78            9               5
# 9985            8          89            9               3
# 9993           10          86            9               9
#
#       assignments_completed  previous_score  exam_score placement_status
# 7                         7              85      100.00           Placed
# 9                        15              69      100.00           Placed
# ...

# %%
df.loc[df["placement_status"].str.contains("Not")]
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 16              3          76            8              10
# 34              4          40            8               7
# 37              5          81            7               5
# 43              2          68            7              11
# 46              2          48            5              10
# ...           ...         ...          ...             ...
# 9963            4          94            5               7
# 9965            1          86            8               2
# 9981            1          53            5               6
# 9986            6          60            5               4
# 9995            2          58            9               7
#
#       assignments_completed  previous_score  exam_score placement_status
# 16                        6              36       63.26       Not Placed
# 34                       15              59       63.20       Not Placed
# ...

# %%
df.loc[df["placement_status"].str.startswith("Not")]
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 16              3          76            8              10
# 34              4          40            8               7
# 37              5          81            7               5
# 43              2          68            7              11
# 46              2          48            5              10
# ...           ...         ...          ...             ...
# 9963            4          94            5               7
# 9965            1          86            8               2
# 9981            1          53            5               6
# 9986            6          60            5               4
# 9995            2          58            9               7
#
#       assignments_completed  previous_score  exam_score placement_status
# 16                        6              36       63.26       Not Placed
# 34                       15              59       63.20       Not Placed
# ...

# %%
df.loc[df["attendance"]<75,["grade"]]="Fail"

# %%
df
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status grade
# 0                        10              62      100.00           Placed  Fail
# 1                         8              56      100.00           Placed  Fail
# ...

# %%
df.loc[df["percentage"]>=70,["grade"]]="High"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.loc[df["percentage"]>=70,["grade"]]="High"
#
# NameError: name 'df' is not defined
